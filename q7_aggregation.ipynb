# %% [markdown]
# # Assignment 5, Question 7: Group Operations & Final Analysis
#
# **Points: 15**
#
# Perform grouped analysis and create summary reports.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Import utilities
from q3_data_utils import load_data, summarize_by_group

df = load_data('data/clinical_trial_raw.csv')
print(f"Loaded {len(df)} patients")

# Prewritten visualization function for grouped analysis
def plot_group_comparison(data, x_col, y_col, title):
    """
    Create a bar chart comparing groups.
    
    Args:
        data: DataFrame with grouped data
        x_col: Column name for x-axis (groups)
        y_col: Column name for y-axis (values)
        title: Chart title
    """
    plt.figure(figsize=(10, 6))
    data.plot(x=x_col, y=y_col, kind='bar')
    plt.title(title)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# 'Data shape: (10000, 18)'
# Loaded 10000 patients

# %% [markdown]
# ## Part 1: Basic Groupby (5 points)
#
# 1. Group by 'site' and calculate mean age, BMI, and blood pressure
# 2. Group by 'intervention_group' and count patients
# 3. Use the `summarize_by_group()` utility to get overall statistics by site

# %%
# TODO: Group by site
groupby_site = df.groupby('site').agg({
    'age': 'mean',
    'bmi': 'mean',
    'systolic_bp':'mean'
}).round(2)

groupby_site.columns = ['age', 'bmi', 'systolic_bp']
groupby_site['avg_systolic_bp'] = (groupby_site['systolic_bp'] / 
                                    groupby_site['age']).round(2)

groupby_site.sort_values('age', ascending=False)
# Out:
#                age    bmi  systolic_bp  avg_systolic_bp
# site
#   site e     83.19  26.33       120.00             1.44
#   site d     81.00  27.18       121.33             1.50
#   site c     80.93  26.36       119.71             1.48
#   Site  A    80.33  25.45       118.55             1.48
# Site_D       77.99  25.17       117.49             1.51
#   SITE D     77.85  25.89       119.51             1.54
#   Site E     75.50  27.10       119.60             1.58
# site b       68.41  25.64       117.09             1.71
# Site D       67.47  25.64       118.02             1.75
#   site a     67.27  25.61       116.70             1.73
# SITE B       63.63  25.67       117.03             1.84
# site d       61.88  25.29       117.21             1.89
# site e       61.86  25.38       117.91             1.91
# Site A       61.44  25.98       117.09             1.91
# SITE A       60.91  26.06       117.09             1.92
# Site C       60.89  25.85       118.51             1.95
# ...

# %%
# TODO: Count by intervention group
groupby_intervention = df.groupby('intervention_group').agg({
    'patient_id': 'sum'
}).round(2)

patient_count = df['intervention_group'].value_counts()
print(patient_count)
# Out:
# intervention_group
# Contrl              802
# TREATMENT B         761
# Treatment  B        760
# Control             751
# treatment b         750
# control             734
# Treatment B         730
# CONTROL             715
# TreatmentA          635
# Treatment A         610
# Treatmen A          592
# treatment a         588
# TREATMENT A         572
#   Treatment B       104
#   Control            95
#   treatment b        90
#   CONTROL            84
#   control            83
#   TREATMENT B        83
#   Contrl             73
#   treatment a        67
#   TreatmentA         66
#   Treatment A        66
#   TREATMENT A        65
#   Treatment  B       64
#   Treatmen A         60
# Name: count, dtype: int64

# %% [markdown]
# **Note:** The `summarize_by_group()` function has an optional `agg_dict` parameter for custom aggregations. If you don't specify it, it will use `.describe()` on numeric columns. You can use `agg_dict={'age': ['mean', 'std'], 'bmi': 'mean'}` for custom aggregations.

# %%
# TODO: Use summarize_by_group utility
summarize_by_group(df, groupby.site, ['age', 'bmi', 'systolic_bp'])
summarize_by_group(df, 'groupby.intervention', ['patient_id'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # TODO: Use summarize_by_group utility
# ----> 2 summarize_by_group(df, 'groupby.site', ['age', 'bmi', 'systolic_bp'])
#       3 summarize_by_group(df, 'groupby.intervention', ['patient_id'])
#
# File /workspaces/ds217-midterm-elimastza/q3_data_utils.py:279, in summarize_by_group(df, group_col, agg_dict)
#     277     return df.groupby(group_col).describe()
#     278 else:
# --> 279     return df.groupby(group_col).agg(agg_dict)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
# ...

# %% [markdown]
# ## Part 2: Multiple Aggregations (5 points)
#
# Group by 'site' and apply multiple aggregations:
# - age: mean, std, min, max
# - bmi: mean, std
# - systolic_bp: mean, median
#
# Display the results in a well-formatted table.

# %%
# TODO: Multiple aggregations

# %% [markdown]
# ## Part 3: Comparative Analysis (5 points)
#
# Compare intervention groups:
# 1. Calculate mean outcome_cvd rate by intervention_group
# 2. Calculate mean adherence_pct by intervention_group
# 3. Create a cross-tabulation of intervention_group vs dropout status
# 4. Visualize the comparison with a bar plot

# %%
# TODO: Intervention group comparisons

# %%
# TODO: Visualization

# %% [markdown]
# ## Part 4: Final Report
#
# Create and save:
# 1. Summary statistics by site → `output/q7_site_summary.csv`
# 2. Intervention group comparison → `output/q7_intervention_comparison.csv`
# 3. Text report with key findings → `output/q7_analysis_report.txt`

# %%
# TODO: Save summary outputs

# %% [markdown]
# ## Summary
#
# What are the 3 most important findings from your analysis?

# %% [markdown]
# **Key Findings:**
#
# 1. TODO
# 2. TODO
# 3. TODO
